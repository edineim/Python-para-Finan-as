# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^DJI', '^IXIC', '^BVSP']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1995-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC         ^DJI       ^IXIC        ^BVSP
# Date
# 1995-01-03  459.109985  3838.479980  743.580017  4098.000000
# 1995-01-04  460.709991  3857.649902  745.840027  3967.899902
# 1995-01-05  460.339996  3850.919922  745.659973  4036.699951
# 1995-01-06  460.679993  3867.409912  749.690002  3827.399902
# 1995-01-09  460.829987  3861.350098  752.090027  3627.800049

# %%
ind_data.tail()
# Out:
#                   ^GSPC          ^DJI         ^IXIC          ^BVSP
# Date
# 2022-08-29  4030.610107  32098.990234  12017.669922  112323.000000
# 2022-08-30  3986.159912  31790.869141  11883.139648  110431.000000
# 2022-08-31  3955.000000  31510.429688  11816.200195  109523.000000
# 2022-09-01  3966.850098  31656.419922  11785.129883  110405.000000
# 2022-09-02  3988.189941  31800.550781  11829.614258  111098.398438

# %%
(ind_data / ind_data.iloc[0]*100).plot(figsize=(15,6));
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1
ind_returns.tail()
# Out:
#                ^GSPC      ^DJI     ^IXIC     ^BVSP
# Date
# 2022-08-29 -0.006666 -0.005712 -0.010216  0.000214
# 2022-08-30 -0.011028 -0.009599 -0.011194 -0.016844
# 2022-08-31 -0.007817 -0.008821 -0.005633 -0.008222
# 2022-09-01  0.002996  0.004633 -0.002629  0.008053
# 2022-09-02  0.005380  0.004553  0.003775  0.006280

# %%
annual_ind_returns = ind_returns.mean()*250
annual_ind_returns
# Out:
# ^GSPC    0.095773
# ^DJI     0.092625
# ^IXIC    0.129433
# ^BVSP    0.160213
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='2020-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2022-08-29  141.690002  4030.610107  32098.990234
# 2022-08-30  140.179993  3986.159912  31790.869141
# 2022-08-31  137.940002  3955.000000  31510.429688
# 2022-09-01  139.639999  3966.850098  31656.419922
# 2022-09-02  140.750000  3987.100098  31785.839844

# %%
(data_2/data_2.iloc[0]*100).plot(figsize=(15,6));
plt.show()
